# %% [markdown]
# ## Problems to solve:
#  * What is the best selling category?
#  * Visualize payment method and order status
#  * Find correlation between payment method and order status
#  * Find a correlation between order date and item category
#  * Find any hidden patterns that are counter intuitive for a layman
#  * Can we predict number of orders, or item category or number of cusomers/amount in advance

# %% [markdown]
# ### Best selling category
#
# The best selling category is *Mobiles & Tablets* with 115710 appearances
#
# * Mobiles & Tablets -----     115710
# * Men's Fashion   -----       92221
# * Women's Fashion -----       59721
# * Appliances           -----  52413
# * Superstore    -----         43613
# * Beauty & Grooming  -----    41496
# * Soghaat         -----       34011
# * Others           -----      29218
# * Home & Living     -----     26504
# * Entertainment     -----     26326
# * Health & Sports   -----     17502
# * Kids & Baby      -----      16494
# * Computing        -----      15933
# * School & Education -----     3478
# * Books           -----        1870
# ![category_frequency-2.png](attachment:category_frequency-2.png)

# %% [markdown]
# ### ORDER STATUS VISUALIZATION
#
# * complete----      233685
# * canceled ----         201249
# * received ----          77290
# * order_refunded ----     59529
# * refund   ----           8050
# * cod  ----               2859
# * paid     ----           1159
# * closed        ----   494
# * payment_review ----       57
# * pending           ----    48
# * processing            ----33
# * holded               ---- 31
# * fraud                 ----10
# * pending_paypal         ----7
# * exchange               ----4
# ![orderst_frequency-2.png](attachment:orderst_frequency-2.png)

# %% [markdown]
# ### PAYMENT METHODS
# * cod     ----             271960
# * Payaxis     ----          97641
# * Easypay         ----      82900
# * jazzwallet        ----    35145
# * easypay_voucher ----      31176
# * bankalfalah     ----      23065
# * jazzvoucher     ----      15633
# * Easypay_MA       ----     14028
# * customercredit   ----      7555
# * apg              ----      1758
# * ublcreditcard    ----       882
# * cashatdoorstep   ----       732
# * mcblite          ----       723
# * mygateway        ----       669
# * internetbanking  ----       472
# * productcredit    ----       125
# * marketingexpense ----        45
# * financesettlement ----       15
# ![paymentmethod-2.png](attachment:paymentmethod-2.png)

# %% [markdown]
# ### Correlation between payment method and order status

# %% [markdown]
# Correlation between Payment method and order status using pearson's method: `0.13258973299895913`
#
# Its safe to say there is no corelation as the number is close to 0

# %% [markdown]
# ### Correlation between order date and item category

# %% [markdown]
# Correlation between Payment method and order status: `-0.03585523235831327`
